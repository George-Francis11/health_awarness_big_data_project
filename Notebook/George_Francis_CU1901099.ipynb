# %% [markdown]
# # Exploring Data

# %%
import pandas as pd
import re
import string
import nltk
import profanity_filter

# %%
df = pd.read_csv("final_data.csv",low_memory = False)

# %%
len(df)
# Out:
# 1126324

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1126324 entries, 0 to 1126323
# Data columns (total 47 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Unnamed: 0        1126324 non-null  int64
#  1   Unnamed: 0.1      1126324 non-null  int64
#  2   Unnamed: 0.1.1    1126324 non-null  int64
#  3   id                1126324 non-null  int64
#  4   conversation_id   1126324 non-null  int64
#  5   created_at        1126324 non-null  object
#  6   date              1126324 non-null  object
#  7   time              680784 non-null   object
#  8   timezone          1126324 non-null  int64
#  9   user_id           1126324 non-null  int64
#  10  username          1126324 non-null  object
#  11  name              1126208 non-null  object
#  12  place             2116 non-null     object
#  13  tweet             1126324 non-null  object
#  14  language          1126324 non-null  object
#  15  mentions          680784 non-null   object
#  16  urls              1126324 non-null  object
#  17  photos            1126324 non-null  object
#  18  replies_count     680784 non-null   float64
#  19  retweets_count    680784 non-null   float64
#  20  likes_count       680784 non-null   float64
#  21  hashtags          1126324 non-null  object
#  22  cashtags          1126324 non-null  object
#  23  link              1126324 non-null  object
#  24  retweet           1126324 non-null  bool
#  25  quote_url         81875 non-null    object
#  26  video             1126324 non-null  int64
#  27  thumbnail         144463 non-null   object
#  28  near              0 non-null        float64
#  29  geo               0 non-null        float64
#  30  source            0 non-null        float64
#  31  user_rt_id        0 non-null        float64
#  32  user_rt           0 non-null        float64
#  33  retweet_id        0 non-null        float64
#  34  reply_to          1126324 non-null  object
#  35  retweet_date      0 non-null        float64
#  36  translate         0 non-null        float64
#  37  trans_src         0 non-null        float64
#  38  trans_dest        0 non-null        float64
#  39  Unnamed: 0.1.1.1  277429 non-null   float64
#  40  user_id_str       445540 non-null   float64
#  41  day               445540 non-null   float64
#  42  hour              445540 non-null   float64
#  43  nlikes            445540 non-null   float64
#  44  nreplies          445540 non-null   float64
#  45  nretweets         445540 non-null   float64
#  46  search            445540 non-null   object
# dtypes: bool(1), float64(20), int64(8), object(18)
# memory usage: 396.4+ MB

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                   id  \
# 0           0             0               0  1104399088915607552
# 1           1             1               0  1116703024783736833
# 2           2             2               0  1119316001844289536
# 3           3             3               0  1113496393015005184
# 4           4             4               0  1115986055268794373
#
#        conversation_id                               created_at        date  \
# 0  1104399088915607552  2019-03-09 17:10:36 Egypt Standard Time  2019-03-09
# 1  1116703024783736833  2019-04-12 16:02:03 Egypt Standard Time  2019-04-12
# 2  1119316001844289536  2019-04-19 21:05:05 Egypt Standard Time  2019-04-19
# 3  1113496393015005184  2019-04-03 19:40:02 Egypt Standard Time  2019-04-03
# 4  1115986055268794373  2019-04-10 16:33:04 Egypt Standard Time  2019-04-10
#
#        time  timezone             user_id  ... trans_src trans_dest  \
# 0  17:10:36       200  843195118924546048  ...       NaN        NaN
# 1  16:02:03       200            34048082  ...       NaN        NaN
# 2  21:05:05       200           107684382  ...       NaN        NaN
# 3  19:40:02       200            34048082  ...       NaN        NaN
# 4  16:33:04       200            34048082  ...       NaN        NaN
#
#   Unnamed: 0.1.1.1 user_id_str day hour nlikes nreplies  nretweets  search
# 0              NaN         NaN NaN  NaN    NaN      NaN        NaN     NaN
# 1              NaN         NaN NaN  NaN    NaN      NaN        NaN     NaN
# 2              NaN         NaN NaN  NaN    NaN      NaN        NaN     NaN
# 3              NaN         NaN NaN  NaN    NaN      NaN        NaN     NaN
# 4              NaN         NaN NaN  NaN    NaN      NaN        NaN     NaN
#
# [5 rows x 47 columns]

# %% [markdown]
#     Select the English language tweets only

# %%
df = df[df["language"]=="en"]

# %%
df["hashtags"]
# Out:
# 0                                       []
# 1          ['troxell', 'txla19', 'edtech']
# 2                   ['bardbits', 'prompt']
# 3                           ['advantage7']
# 4          ['txla19', 'troxell', 'edtech']
#                         ...
# 1125933                                 []
# 1125984                                 []
# 1125999                                 []
# 1126294                                 []
# 1126314                                 []
# Name: hashtags, Length: 703318, dtype: object

# %% [markdown]
# # Dropping unneeded columns

# %% [markdown]
#     We only chose the columns we will need and ignore the rest

# %%
imp_df = df[["tweet","username","date","hashtags"]]

# %%
imp_df.head()
# Out:
#                                                tweet        username  \
# 0   https://t.co/23WtwZ02H8 "The Artful Covid -- ...  best_of_mltshp
# 1  We lived in a “connected” world. Classrooms to...    bluum_edtech
# 2  Stones cascade~ Form their own soliloquy, Covi...    demonwings17
# 3  The new Covid HDBaseT Smart System is an all-i...    bluum_edtech
# 4  Going to #TXLA19? Visit #Troxell booth 2317. S...    bluum_edtech
#
#          date                         hashtags
# 0  2019-03-09                               []
# 1  2019-04-12  ['troxell', 'txla19', 'edtech']
# 2  2019-04-19           ['bardbits', 'prompt']
# 3  2019-04-03                   ['advantage7']
# 4  2019-04-10  ['txla19', 'troxell', 'edtech']

# %% [markdown]
# # Clean the tweets

# %% [markdown]
#     Here we need to remove all the punctuation from the tweets, however, if we remove the "@" we will not be able to identify mentions
#     So we left it there and will remove the mentions completely in a further step

# %%
punc = []
for char in string.punctuation[0]:
    if char != "@":
        punc.append(char)
punc = "".join(punc)

# %%
def remove_punctuation(tweet):
    global punc
    tweet = "".join([char for char in tweet if char not in punc])
    return tweet

# %%
def remove_mentions(tweet):
    tweet = " ".join(word for word in tweet.split() if word[0] != "@")
    return tweet

# %%
def cleanhttp(sentence):
    sentence = re.sub("(https?://[^\s]+)","",sentence)
    return sentence

# %%
def cleanHtml(sentence): #tweets may unclude html content, so this regex removes anything between the html brackets "<>"
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, ' ', str(sentence))
    return cleantext

# %%
def cleanPunc(sentence): #removes all the punctuation from the sentence
    cleaned = re.sub(r'[?|!|\'|"|#]',r' ',sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/|_|-]',r' ',cleaned)
    cleaned = cleaned.strip()
    cleaned = cleaned.replace("\n"," ")
    return cleaned

# %%
def keepAlpha(sentence): #This removes any numbers, non ascii letter and leaves only alphabet chars
    alpha_sent = ""
    for word in sentence.split():
        alpha_word = re.sub('[^a-z A-Z]+', ' ', word)
        alpha_sent += alpha_word
        alpha_sent += " "
    alpha_sent = alpha_sent.strip()
    return alpha_sent

# %%
def decontraction(text): # clears teh abbreviations such as isn't => is not
    text = re.sub(r"won\'t", "will not", text)
    text = re.sub(r"can\'t", "can not", text)
    text = re.sub(r"n\'t", " not", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'s", " is", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'t", " not", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'m", " am", text)
    
    return text

# %% [markdown]
#     apply all the above functions to the tweets

# %%
imp_df['clean_tweet'] = imp_df['tweet'].str.lower()
imp_df['clean_tweet'] = imp_df['clean_tweet'].apply(remove_mentions)
imp_df['clean_tweet'] = imp_df['clean_tweet'].apply(cleanhttp)
imp_df['clean_tweet'] = imp_df['clean_tweet'].apply(cleanHtml)
imp_df['clean_tweet'] = imp_df['clean_tweet'].apply(remove_punctuation)
imp_df['clean_tweet'] = imp_df['clean_tweet'].apply(keepAlpha)
imp_df['clean_tweet'] = imp_df['clean_tweet'].apply(decontraction)

# %%
imp_df.head()
# Out:
#                                                tweet        username  \
# 0   https://t.co/23WtwZ02H8 "The Artful Covid -- ...  best_of_mltshp
# 1  We lived in a “connected” world. Classrooms to...    bluum_edtech
# 2  Stones cascade~ Form their own soliloquy, Covi...    demonwings17
# 3  The new Covid HDBaseT Smart System is an all-i...    bluum_edtech
# 4  Going to #TXLA19? Visit #Troxell booth 2317. S...    bluum_edtech
#
#          date                         hashtags  \
# 0  2019-03-09                               []
# 1  2019-04-12  ['troxell', 'txla19', 'edtech']
# 2  2019-04-19           ['bardbits', 'prompt']
# 3  2019-04-03                   ['advantage7']
# 4  2019-04-10  ['txla19', 'troxell', 'edtech']
#
#                                          clean_tweet
# 0                   the artful covid false knees via
# 1  we lived in a  connected  world classrooms tod...
# 2  stones cascade form their own soliloquy covidc...
# 3  the new covid hdbaset smart system is an allin...
# 4  going to txla  visit troxell booth   see our t...

# %% [markdown]
#     Rearrange the columns

# %%
clean_df = imp_df[["username","tweet","clean_tweet","hashtags","date"]]

# %%
clean_df.head()
# Out:
#          username                                              tweet  \
# 0  best_of_mltshp   https://t.co/23WtwZ02H8 "The Artful Covid -- ...
# 1    bluum_edtech  We lived in a “connected” world. Classrooms to...
# 2    demonwings17  Stones cascade~ Form their own soliloquy, Covi...
# 3    bluum_edtech  The new Covid HDBaseT Smart System is an all-i...
# 4    bluum_edtech  Going to #TXLA19? Visit #Troxell booth 2317. S...
#
#                                          clean_tweet  \
# 0                   the artful covid false knees via
# 1  we lived in a  connected  world classrooms tod...
# 2  stones cascade form their own soliloquy covidc...
# 3  the new covid hdbaset smart system is an allin...
# 4  going to txla  visit troxell booth   see our t...
#
#                           hashtags        date
# 0                               []  2019-03-09
# 1  ['troxell', 'txla19', 'edtech']  2019-04-12
# 2           ['bardbits', 'prompt']  2019-04-19
# 3                   ['advantage7']  2019-04-03
# 4  ['txla19', 'troxell', 'edtech']  2019-04-10

# %% [markdown]
#     Remove the original tweet since we have the clean tweet

# %%
clean_df.drop(["tweet"],axis=1,inplace=True)
# Out:
# C:\Users\George\.conda\envs\myenv\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
clean_df.to_csv("cleaned_data.csv")

# %% [markdown]
# ## Removing stopping words and explicit language

# %%
stopping = nltk.corpus.stopwords.words("english")
stopping = list(set(stopping))

# %%
def remove_stopping_words(tweet): # stopping words are skipped and the original tweet is returned without those stopping words
    global stopping
    return " ".join([x for x in tweet.split() if x not in stopping])

# %%
with open("untitled.txt","r") as swears:
    data = swears.readlines()

# %%
swears = []
for word in data:
    swears.append(word.replace("\n","")) # lines in a file ends with the "\n" character so we remove it

# %%
clean_df = pd.read_csv("cleaned_data.csv")
# Out:
# C:\Users\George\.conda\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
len(swears)
# Out:
# 835

# %%
len(clean_df[clean_df["swears_count"]>0])

# %% [markdown]
#     As seen above, nearly 5% of the tweets contains profanity, so removing them is needed as they might appear in statistics and graphs later on
#     HOWEVER, swears play an important role when it comes to sentiment analysis. so we remove them from the tweet and add a new column to count them

# %%
def count_profanity_words(sentence):
    global swears
    counter =0
    for word in sentence.split():
        if word in swears:
            counter +=1
    return counter

def filter_profanity_words(sentence):
    global swears
    clean_sentence = []
    for word in sentence.split():
        if word not in swears:
            clean_sentence.append(word)
    return " ".join(clean_sentence)

# %%
print(filter_profanity_words("hello fucking worlds"))
# Out:
# hello worlds

# %%
clean_df["swears_count"] = clean_df["clean_tweet"].fillna("").apply(count_profanity_words)
clean_df["clean_tweet"] = clean_df["clean_tweet"].fillna("").apply(filter_profanity_words)

# %% [markdown]
# the following line will replace all the swears with a specific word, since I don't want to remove them as they contribute to the sentiment analysis

# %%
clean_df.head()
# Out:
#          username                                        clean_tweet  \
# 0  best_of_mltshp                       artful covid false knees via
# 1    bluum_edtech  lived connected world classrooms today incredi...
# 2    demonwings17  stones cascade form soliloquy covidcrow shriek...
# 3    bluum_edtech  new covid hdbaset smart system allinone av con...
# 4    bluum_edtech  going txla visit troxell booth see team austin...
#
#                           hashtags     date  swears_count  year  month day
# 0                               []  2019-03             0  2019      3   9
# 1  ['troxell', 'txla19', 'edtech']  2019-04             0  2019      4  12
# 2           ['bardbits', 'prompt']  2019-04             0  2019      4  19
# 3                   ['advantage7']  2019-04             0  2019      4   3
# 4  ['txla19', 'troxell', 'edtech']  2019-04             0  2019      4  10

# %%
remove_stopping_words("This is a report")

# %%
clean_df["clean_tweet"] = clean_df["clean_tweet"].fillna("").apply(remove_stopping_words)

# %%
clean_df.head()
# Out:
#          username                                        clean_tweet  \
# 0  best_of_mltshp                       artful covid false knees via
# 1    bluum_edtech  lived connected world classrooms today incredi...
# 2    demonwings17  stones cascade form soliloquy covidcrow shriek...
# 3    bluum_edtech  new covid hdbaset smart system allinone av con...
# 4    bluum_edtech  going txla visit troxell booth see team austin...
#
#                           hashtags     date  swears_count  year month day
# 0                               []  2019-03             0  2019    03  09
# 1  ['troxell', 'txla19', 'edtech']  2019-04             0  2019    04  12
# 2           ['bardbits', 'prompt']  2019-04             0  2019    04  19
# 3                   ['advantage7']  2019-04             0  2019    04  03
# 4  ['txla19', 'troxell', 'edtech']  2019-04             0  2019    04  10

# %%
def split_date(date):
    split = date.split("-")
    year = split[0]
    month = split[1]
    day = split[2]
    return pd.Series([year, month, day])

def remove_days(date):
    return "-".join(date.split("-")[0:-1])

# %%
remove_days("2019-03-20")
# Out:
# '2019-03'

# %%
clean_df[["year","month","day"]] = clean_df["date"].apply(split_date)

# %%
clean_df["date"] = clean_df["date"].apply(remove_days)

# %%
clean_df.to_csv("cleaned_data.csv",index = False)

# %% [markdown]
# ## Stemming

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
stemmer = SnowballStemmer("english")

# %%
def stem_tweets(tweet): #stemming will remove the prefix and suffix of the words so we end up with the root, this helps in grouping the words together
    stemmer = SnowballStemmer("english")
    words = tweet.split()
    stemmed = []
    for word in words:
        if word == "swearing":
            stemmed.append(word)
        else:
            stemmed.append(stemmer.stem(word))
    return " ".join(stemmed)

# %%
clean_df["clean_tweet"] = clean_df["clean_tweet"].fillna("").apply(stem_tweets)

# %%
clean_df.head()
# Out:
#    Unnamed: 0        username  \
# 0           0  best_of_mltshp
# 1           1    bluum_edtech
# 2           2    demonwings17
# 3           3    bluum_edtech
# 4           4    bluum_edtech
#
#                                          clean_tweet  \
# 0                art covid fals knee via robotmachin
# 1  live connect world classroom today incred tech...
# 2  stone cascad form soliloquy covidcrow shriek f...
# 3  new covid hdbaset smart system allinon av cont...
# 4  go txla visit troxel booth see team austin con...
#
#                           hashtags        date  swears_count
# 0                               []  2019-03-09             0
# 1  ['troxell', 'txla19', 'edtech']  2019-04-12             0
# 2           ['bardbits', 'prompt']  2019-04-19             0
# 3                   ['advantage7']  2019-04-03             0
# 4  ['txla19', 'troxell', 'edtech']  2019-04-10             0

# %%
clean_df.to_csv("cleaned_data.csv")

# %% [markdown]
# # Sentiment Analysis

# %%
clean_df = pd.read_csv("cleaned_data.csv",low_memory=False)

# %%
clean_df.head()
# Out:
#          username                                        clean_tweet  \
# 0  best_of_mltshp                       artful covid false knees via
# 1    bluum_edtech  lived connected world classrooms today incredi...
# 2    demonwings17  stones cascade form soliloquy covidcrow shriek...
# 3    bluum_edtech  new covid hdbaset smart system allinone av con...
# 4    bluum_edtech  going txla visit troxell booth see team austin...
#
#                           hashtags     date  swears_count  year  month day
# 0                               []  2019-03             0  2019      3  09
# 1  ['troxell', 'txla19', 'edtech']  2019-04             0  2019      4  12
# 2           ['bardbits', 'prompt']  2019-04             0  2019      4  19
# 3                   ['advantage7']  2019-04             0  2019      4  03
# 4  ['txla19', 'troxell', 'edtech']  2019-04             0  2019      4  10

# %% [markdown]
#     We need to sentiment analysis the tweets that talk about Covid, since the sentiment analysis is about Covid specifically not health awareness in General!

# %%
def find_covid(sentence):
    for word in sentence.split():
        if "covid" in word:
            return True
    return False

# %%
clean_df["include_covid"] = clean_df.clean_tweet.fillna("").apply(find_covid) # we flag the tweets with "covid" word so we can filter them

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from nltk.stem import SnowballStemmer
nltk.download("vader_lexicon")
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# /usr/local/lib/python3.7/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
# True

# %%
covid_tweets = clean_df[clean_df["include_covid"] == True] # filter those tweets to another DF

# %% [markdown]
#     We analyze each tweet,add the factor of the swears, decide whether (positive/negative/neutral), and then add it to the respective df

# %%
def remove_positive(tweet):
    answer = []
    for word in tweet.split():
        if word != "positive":
            answer.append(word)
    return " ".join(answer)

# %%
remove_positive("I am positive happy")
# Out:
# 'I am happy'

# %%
covid_tweets["clean_tweet"] = covid_tweets["clean_tweet"].apply(remove_positive)

# %%
covid_tweets.head()
# Out:
#          username                                        clean_tweet  \
# 0  best_of_mltshp                       artful covid false knees via
# 1    bluum_edtech  lived connected world classrooms today incredi...
# 2    demonwings17  stones cascade form soliloquy covidcrow shriek...
# 3    bluum_edtech  new covid hdbaset smart system allinone av con...
# 4    bluum_edtech  going txla visit troxell booth see team austin...
#
#                           hashtags     date  swears_count  year  month day  \
# 0                               []  2019-03             0  2019      3   9
# 1  ['troxell', 'txla19', 'edtech']  2019-04             0  2019      4  12
# 2           ['bardbits', 'prompt']  2019-04             0  2019      4  19
# 3                   ['advantage7']  2019-04             0  2019      4   3
# 4  ['txla19', 'troxell', 'edtech']  2019-04             0  2019      4  10
#
#    include_covid
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True

# %%
len(covid_tweets)

# %%
covid_tweets.to_csv("covid_tweets.csv",index = False)

# %%
covid_tweets = pd.read_csv("covid_tweets.csv", low_memory=False)

# %%
positive = negative = 0
neutral_tweets =[]
positive_tweets =[]
negative_tweets = []
neutral_tags =[]
positive_tags =[]
negative_tags = []
tweets_list = covid_tweets.clean_tweet.values
swears_count_list = covid_tweets.swears_count.values
hashtags = covid_tweets.hashtags.values
for i in range(0,len(covid_tweets)):
    tweet = tweets_list[i]
    hashtag = hashtags[i]
    sentiment = SentimentIntensityAnalyzer().polarity_scores(tweet)
    negative = sentiment["neg"] + (0.1*swears_count_list[i])
    positive = sentiment["pos"]
    if positive > negative:
        positive_tweets.append(tweet)
        positive_tags.append(hashtag)
    elif positive < negative:
        negative_tweets.append(tweet)
        negative_tags.append(hashtag)
    else:
        neutral_tweets.append(tweet)
        neutral_tags.append(hashtag)

# %% [markdown]
#     Here are the count of each category:

# %%
neutral_df = pd.DataFrame(neutral_tweets)
positive_df = pd.DataFrame(positive_tweets)
negative_df = pd.DataFrame(negative_tweets)

# %%
print(len(negative_df),len(positive_df),len(neutral_df))
# Out:
# 204156 187102 106541

# %%
neutral_df["hashtags"] = neutral_tags
positive_df["hashtags"] = positive_tags
negative_df["hashtags"] = negative_tags

# %%
neutral_df.head()
# Out:
#                                                    0  \
# 0                       artful covid false knees via
# 1  imagine trying mansplain covid researcher isnt...
# 2  new symbol updates covid cad design documentat...
# 3  world health organization says official name d...
# 4  name disease covid spell covid hyphen one nine...
#
#                                             hashtags
# 0                                                 []
# 1                                                 []
# 2  ['cad', 'design', 'documentation', 'software',...
# 3                                                 []
# 4                                                 []

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
#     Create a pie chart to represent the distribution of the tweets

# %%
data = [len(neutral_df),len(negative_df),len(positive_df)]
total_length = len(neutral_df)+len(positive_df)+len(negative_df)
labels = [f"neutral tweets: {round(float(len(neutral_df))/float(total_length),3)*100}%",
          f"negative tweets: {round(float(len(negative_df))/float(total_length),3)*100}%",
          f"positive tweets: {round(float(len(positive_df))/float(total_length),3)*100}%"]

# %%
colors = sns.color_palette('pastel')[0:5]

#create pie chart
plt.pie(data, labels = labels, colors = sns.color_palette("bright"), autopct='%0.1f%%')
plt.show()

# %%
positive_df = pd.read_csv("positive_tweets.csv")
negative_df = pd.read_csv("negative_tweets.csv")
neutral_df = pd.read_csv("neutral_tweets.csv")

# %%
positive_df.head()
# Out:
#                                                    0  \
# 0  lived connected world classrooms today incredi...
# 1  stones cascade form soliloquy covidcrow shriek...
# 2  new covid hdbaset smart system allinone av con...
# 3  going txla visit troxell booth see team austin...
# 4                      love covids iridescence lt lt
#
#                           hashtags
# 0  ['troxell', 'txla19', 'edtech']
# 1           ['bardbits', 'prompt']
# 2                   ['advantage7']
# 3  ['txla19', 'troxell', 'edtech']
# 4                               []

# %%
from wordcloud import WordCloud,STOPWORDS

# %% [markdown]
#     Since wordcloud need a continuous string not a column in the DF, we will join all the tweets of each df into a gigantic string

# %%
positive_data = " ".join(positive_df[0])
negative_data = " ".join(negative_df[0])
neutral_data = " ".join(neutral_df[0])

# %%
positive_tags

# %% [markdown]
# Add the stopping words to prevent them from showing up in the wordcloud, EX: we used covid to find these tweets, so all of them include covid. However, covid is not a helpful word to include in the word cloud

# %%
stoppingwords = list(set(STOPWORDS))
stoppingwords.extend(["vaccine","covid","tested"])

# %%
positive_cloud = WordCloud(width=3000,height=3000,background_color="white",stopwords=stoppingwords).generate(positive_data)
negative_cloud = WordCloud(width=3000,height=3000,background_color="white",stopwords=stoppingwords).generate(negative_data)
neutral_cloud = WordCloud(width=3000,height=3000,background_color="white",stopwords=stoppingwords).generate(neutral_data)

# %%
clouds = [positive_cloud,negative_cloud,neutral_cloud]

# %%
plt.figure(figsize=(15,10))
plt.imshow(positive_cloud, interpolation="bilinear")
plt.title("Word cloud of positive tweets", fontsize = 30, pad = 20)
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.imshow(negative_cloud, interpolation="bilinear")
plt.title("Word cloud of negative tweets", fontsize = 30, pad = 20)
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.imshow(neutral_cloud, interpolation="bilinear")
plt.title("Word cloud of neutral tweets", fontsize = 30, pad = 20)
plt.axis("off")
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
for i in range(3):
    ax = fig.add_subplot(2,2,i+1)
    ax.imshow(clouds[i])
    ax.axis('off')

# %%
neutral_df.to_csv("neutral_df.csv")
positive_df.to_csv("positive_df.csv")
negative_df.to_csv("negative_df.csv")

# %%
from collections import Counter

# %%
def generate_frequency(text):
  freq = {}
  for word in text.split():
    if len(word) >2:
      if word in freq.keys():
        freq[word] = freq[word] + 1
      else:
        freq[word] = 1
  return freq

# %%
positive_freq = generate_frequency(positive_data)
neutral_freq = generate_frequency(neutral_data)
negative_freq = generate_frequency(negative_data)

# %%
positive_freq.most_common(10)
# Out:
# [('covid', 203367),
#  ('like', 23238),
#  ('people', 22680),
#  ('get', 18869),
#  ('amp', 16193),
#  ('got', 11750),
#  ('one', 11747),
#  ('still', 11713),
#  ('vaccine', 10383),
#  ('would', 10101)]

# %%
positive_freq = Counter(positive_freq)
neutral_freq = Counter(neutral_freq)
negative_freq = Counter(negative_freq)

# %%
positive_words_df = pd.DataFrame(positive_freq.most_common(50))
positive_words_df.columns = ['positive_word','freq']
positive_words_df.style.background_gradient(cmap='Greens', low=0.0, high=1.0,vmin=0.7, vmax=15000)
# Out:
# <style type="text/css">
# #T_24eee_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_24eee_row1_col1 {
#   background-color: #1c8540;
#   color: #f1f1f1;
# }
# #T_24eee_row2_col1 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_24eee_row3_col1 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_24eee_row4_col1 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_24eee_row5_col1, #T_24eee_row6_col1 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_24eee_row7_col1 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_24eee_row8_col1 {
#   background-color: #aadda4;
#   color: #000000;
# }
# #T_24eee_row9_col1 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_24eee_row10_col1, #T_24eee_row11_col1 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_24eee_row12_col1 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# #T_24eee_row13_col1 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_24eee_row14_col1 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_24eee_row15_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_24eee_row16_col1 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_24eee_row17_col1 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_24eee_row18_col1 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_24eee_row19_col1 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_24eee_row20_col1 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_24eee_row21_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_24eee_row22_col1, #T_24eee_row23_col1, #T_24eee_row24_col1, #T_24eee_row25_col1, #T_24eee_row26_col1 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_24eee_row27_col1, #T_24eee_row28_col1 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_24eee_row29_col1, #T_24eee_row30_col1, #T_24eee_row31_col1 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_24eee_row32_col1, #T_24eee_row33_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_24eee_row34_col1, #T_24eee_row35_col1, #T_24eee_row36_col1 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_24eee_row37_col1 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_24eee_row38_col1, #T_24eee_row39_col1 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_24eee_row40_col1, #T_24eee_row41_col1 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_24eee_row42_col1 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_24eee_row43_col1 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_24eee_row44_col1, #T_24eee_row45_col1 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_24eee_row46_col1, #T_24eee_row47_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_24eee_row48_col1 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_24eee_row49_col1 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# </style>
# <table id="T_24eee_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >positive_word</th>
#       <th class="col_heading level0 col1" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24eee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_24eee_row0_col0" class="data row0 col0" >covid</td>
#       <td id="T_24eee_row0_col1" class="data row0 col1" >203367</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_24eee_row1_col0" class="data row1 col0" >like</td>
#       <td id="T_24eee_row1_col1" class="data row1 col1" >23238</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_24eee_row2_col0" class="data row2 col0" >people</td>
#       <td id="T_24eee_row2_col1" class="data row2 col1" >22680</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_24eee_row3_col0" class="data row3 col0" >get</td>
#       <td id="T_24eee_row3_col1" class="data row3 col1" >18869</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_24eee_row4_col0" class="data row4 col0" >amp</td>
#       <td id="T_24eee_row4_col1" class="data row4 col1" >16193</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_24eee_row5_col0" class="data row5 col0" >got</td>
#       <td id="T_24eee_row5_col1" class="data row5 col1" >11750</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_24eee_row6_col0" class="data row6 col0" >one</td>
#       <td id="T_24eee_row6_col1" class="data row6 col1" >11747</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_24eee_row7_col0" class="data row7 col0" >still</td>
#       <td id="T_24eee_row7_col1" class="data row7 col1" >11713</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_24eee_row8_col0" class="data row8 col0" >vaccine</td>
#       <td id="T_24eee_row8_col1" class="data row8 col1" >10383</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_24eee_row9_col0" class="data row9 col0" >would</td>
#       <td id="T_24eee_row9_col1" class="data row9 col1" >10101</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_24eee_row10_col0" class="data row10 col0" >good</td>
#       <td id="T_24eee_row10_col1" class="data row10 col1" >10064</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_24eee_row11_col0" class="data row11 col0" >know</td>
#       <td id="T_24eee_row11_col1" class="data row11 col1" >10044</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_24eee_row12_col0" class="data row12 col0" >time</td>
#       <td id="T_24eee_row12_col1" class="data row12 col1" >9895</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_24eee_row13_col0" class="data row13 col0" >long</td>
#       <td id="T_24eee_row13_col1" class="data row13 col1" >9839</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_24eee_row14_col0" class="data row14 col0" >health</td>
#       <td id="T_24eee_row14_col1" class="data row14 col1" >9593</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_24eee_row15_col0" class="data row15 col0" >well</td>
#       <td id="T_24eee_row15_col1" class="data row15 col1" >9464</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_24eee_row16_col0" class="data row16 col0" >vaccination</td>
#       <td id="T_24eee_row16_col1" class="data row16 col1" >9209</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_24eee_row17_col0" class="data row17 col0" >cases</td>
#       <td id="T_24eee_row17_col1" class="data row17 col1" >8103</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_24eee_row18_col0" class="data row18 col0" >new</td>
#       <td id="T_24eee_row18_col1" class="data row18 col1" >8038</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_24eee_row19_col0" class="data row19 col0" >mask</td>
#       <td id="T_24eee_row19_col1" class="data row19 col1" >7913</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_24eee_row20_col0" class="data row20 col0" >even</td>
#       <td id="T_24eee_row20_col1" class="data row20 col1" >7808</td>
#     </tr>
#     <tr>
#       <th id="T_24eee_level0_row21" class="row_heading level0 row21" >21</th>

# %%
negative_words_df = pd.DataFrame(negative_freq.most_common(50))
negative_words_df.columns = ['negative_word','freq']
negative_words_df.style.background_gradient(cmap='Reds', low=0.0, high=0.6,vmin=0.7, vmax=15000)
# Out:
# <style type="text/css">
# #T_27fce_row0_col1, #T_27fce_row1_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_27fce_row2_col1 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_27fce_row3_col1 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_27fce_row4_col1 {
#   background-color: #f6563d;
#   color: #f1f1f1;
# }
# #T_27fce_row5_col1 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_27fce_row6_col1 {
#   background-color: #fa6648;
#   color: #f1f1f1;
# }
# #T_27fce_row7_col1 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# #T_27fce_row8_col1 {
#   background-color: #fb7555;
#   color: #f1f1f1;
# }
# #T_27fce_row9_col1 {
#   background-color: #fb7656;
#   color: #f1f1f1;
# }
# #T_27fce_row10_col1 {
#   background-color: #fb7a5a;
#   color: #f1f1f1;
# }
# #T_27fce_row11_col1 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_27fce_row12_col1, #T_27fce_row13_col1 {
#   background-color: #fc8060;
#   color: #f1f1f1;
# }
# #T_27fce_row14_col1 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_27fce_row15_col1, #T_27fce_row16_col1 {
#   background-color: #fc8565;
#   color: #f1f1f1;
# }
# #T_27fce_row17_col1 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_27fce_row18_col1 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_27fce_row19_col1 {
#   background-color: #fc9777;
#   color: #000000;
# }
# #T_27fce_row20_col1, #T_27fce_row21_col1, #T_27fce_row22_col1 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_27fce_row23_col1 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_27fce_row24_col1, #T_27fce_row25_col1 {
#   background-color: #fca183;
#   color: #000000;
# }
# #T_27fce_row26_col1 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_27fce_row27_col1, #T_27fce_row28_col1 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_27fce_row29_col1 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_27fce_row30_col1, #T_27fce_row31_col1 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_27fce_row32_col1 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_27fce_row33_col1, #T_27fce_row34_col1 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_27fce_row35_col1 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_27fce_row36_col1 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_27fce_row37_col1 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_27fce_row38_col1, #T_27fce_row39_col1 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_27fce_row40_col1, #T_27fce_row41_col1, #T_27fce_row42_col1, #T_27fce_row43_col1, #T_27fce_row44_col1, #T_27fce_row45_col1 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_27fce_row46_col1, #T_27fce_row47_col1 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_27fce_row48_col1, #T_27fce_row49_col1 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# </style>
# <table id="T_27fce_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >negative_word</th>
#       <th class="col_heading level0 col1" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27fce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27fce_row0_col0" class="data row0 col0" >covid</td>
#       <td id="T_27fce_row0_col1" class="data row0 col1" >226237</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_27fce_row1_col0" class="data row1 col0" >people</td>
#       <td id="T_27fce_row1_col1" class="data row1 col1" >34632</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_27fce_row2_col0" class="data row2 col0" >amp</td>
#       <td id="T_27fce_row2_col1" class="data row2 col1" >18543</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_27fce_row3_col0" class="data row3 col0" >get</td>
#       <td id="T_27fce_row3_col1" class="data row3 col1" >18365</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_27fce_row4_col0" class="data row4 col0" >still</td>
#       <td id="T_27fce_row4_col1" class="data row4 col1" >13241</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_27fce_row5_col0" class="data row5 col0" >one</td>
#       <td id="T_27fce_row5_col1" class="data row5 col1" >12958</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_27fce_row6_col0" class="data row6 col0" >like</td>
#       <td id="T_27fce_row6_col1" class="data row6 col1" >12209</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_27fce_row7_col0" class="data row7 col0" >got</td>
#       <td id="T_27fce_row7_col1" class="data row7 col1" >11911</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_27fce_row8_col0" class="data row8 col0" >know</td>
#       <td id="T_27fce_row8_col1" class="data row8 col1" >11246</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_27fce_row9_col0" class="data row9 col0" >long</td>
#       <td id="T_27fce_row9_col1" class="data row9 col1" >11151</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_27fce_row10_col0" class="data row10 col0" >death</td>
#       <td id="T_27fce_row10_col1" class="data row10 col1" >10851</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_27fce_row11_col0" class="data row11 col0" >many</td>
#       <td id="T_27fce_row11_col1" class="data row11 col1" >10618</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_27fce_row12_col0" class="data row12 col0" >died</td>
#       <td id="T_27fce_row12_col1" class="data row12 col1" >10401</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_27fce_row13_col0" class="data row13 col0" >would</td>
#       <td id="T_27fce_row13_col1" class="data row13 col1" >10325</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_27fce_row14_col0" class="data row14 col0" >vaccine</td>
#       <td id="T_27fce_row14_col1" class="data row14 col1" >10151</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_27fce_row15_col0" class="data row15 col0" >time</td>
#       <td id="T_27fce_row15_col1" class="data row15 col1" >9993</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_27fce_row16_col0" class="data row16 col0" >even</td>
#       <td id="T_27fce_row16_col1" class="data row16 col1" >9945</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_27fce_row17_col0" class="data row17 col0" >deaths</td>
#       <td id="T_27fce_row17_col1" class="data row17 col1" >9563</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_27fce_row18_col0" class="data row18 col0" >dont</td>
#       <td id="T_27fce_row18_col1" class="data row18 col1" >8932</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_27fce_row19_col0" class="data row19 col0" >think</td>
#       <td id="T_27fce_row19_col1" class="data row19 col1" >8696</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_27fce_row20_col0" class="data row20 col0" >years</td>
#       <td id="T_27fce_row20_col1" class="data row20 col1" >8306</td>
#     </tr>
#     <tr>
#       <th id="T_27fce_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_27fce_row21_col0" class="data row21

# %%
neutral_words_df = pd.DataFrame(neutral_freq.most_common(50))
neutral_words_df.columns = ['neutral_word','freq']
neutral_words_df.style.background_gradient(cmap='Blues', low=0.0, high=1,vmin=0.7, vmax=5000)
# Out:
# <style type="text/css">
# #T_662eb_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_662eb_row1_col1 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_662eb_row2_col1 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_662eb_row3_col1 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_662eb_row4_col1 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_662eb_row5_col1 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_662eb_row6_col1 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_662eb_row7_col1 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_662eb_row8_col1 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_662eb_row9_col1 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_662eb_row10_col1 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_662eb_row11_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_662eb_row12_col1 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_662eb_row13_col1 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_662eb_row14_col1 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_662eb_row15_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_662eb_row16_col1, #T_662eb_row17_col1 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_662eb_row18_col1 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_662eb_row19_col1, #T_662eb_row20_col1 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_662eb_row21_col1 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_662eb_row22_col1 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_662eb_row23_col1 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_662eb_row24_col1 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_662eb_row25_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_662eb_row26_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_662eb_row27_col1, #T_662eb_row28_col1, #T_662eb_row29_col1 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_662eb_row30_col1, #T_662eb_row31_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_662eb_row32_col1 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_662eb_row33_col1 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_662eb_row34_col1, #T_662eb_row35_col1, #T_662eb_row36_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_662eb_row37_col1, #T_662eb_row38_col1 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_662eb_row39_col1, #T_662eb_row40_col1, #T_662eb_row41_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_662eb_row42_col1, #T_662eb_row43_col1, #T_662eb_row44_col1 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_662eb_row45_col1, #T_662eb_row46_col1, #T_662eb_row47_col1, #T_662eb_row48_col1 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_662eb_row49_col1 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# </style>
# <table id="T_662eb_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >neutral_word</th>
#       <th class="col_heading level0 col1" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_662eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_662eb_row0_col0" class="data row0 col0" >covid</td>
#       <td id="T_662eb_row0_col1" class="data row0 col1" >113175</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_662eb_row1_col0" class="data row1 col0" >cases</td>
#       <td id="T_662eb_row1_col1" class="data row1 col1" >7040</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_662eb_row2_col0" class="data row2 col0" >new</td>
#       <td id="T_662eb_row2_col1" class="data row2 col1" >6948</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_662eb_row3_col0" class="data row3 col0" >vaccination</td>
#       <td id="T_662eb_row3_col1" class="data row3 col1" >6148</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_662eb_row4_col0" class="data row4 col0" >vaccine</td>
#       <td id="T_662eb_row4_col1" class="data row4 col1" >5953</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_662eb_row5_col0" class="data row5 col0" >people</td>
#       <td id="T_662eb_row5_col1" class="data row5 col1" >5596</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_662eb_row6_col0" class="data row6 col0" >get</td>
#       <td id="T_662eb_row6_col1" class="data row6 col1" >5294</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_662eb_row7_col0" class="data row7 col0" >got</td>
#       <td id="T_662eb_row7_col1" class="data row7 col1" >4711</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_662eb_row8_col0" class="data row8 col0" >deaths</td>
#       <td id="T_662eb_row8_col1" class="data row8 col1" >4253</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_662eb_row9_col0" class="data row9 col0" >tests</td>
#       <td id="T_662eb_row9_col1" class="data row9 col1" >3945</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_662eb_row10_col0" class="data row10 col0" >long</td>
#       <td id="T_662eb_row10_col1" class="data row10 col1" >3741</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_662eb_row11_col0" class="data row11 col0" >still</td>
#       <td id="T_662eb_row11_col1" class="data row11 col1" >3554</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_662eb_row12_col0" class="data row12 col0" >know</td>
#       <td id="T_662eb_row12_col1" class="data row12 col1" >3509</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_662eb_row13_col0" class="data row13 col0" >pelosi</td>
#       <td id="T_662eb_row13_col1" class="data row13 col1" >3401</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_662eb_row14_col0" class="data row14 col0" >vaccinated</td>
#       <td id="T_662eb_row14_col1" class="data row14 col1" >3308</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_662eb_row15_col0" class="data row15 col0" >health</td>
#       <td id="T_662eb_row15_col1" class="data row15 col1" >3223</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_662eb_row16_col0" class="data row16 col0" >one</td>
#       <td id="T_662eb_row16_col1" class="data row16 col1" >3196</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_662eb_row17_col0" class="data row17 col0" >test</td>
#       <td id="T_662eb_row17_col1" class="data row17 col1" >3175</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_662eb_row18_col0" class="data row18 col0" >amp</td>
#       <td id="T_662eb_row18_col1" class="data row18 col1" >2934</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_662eb_row19_col0" class="data row19 col0" >via</td>
#       <td id="T_662eb_row19_col1" class="data row19 col1" >2886</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_662eb_row20_col0" class="data row20 col0" >pandemic</td>
#       <td id="T_662eb_row20_col1" class="data row20 col1" >2859</td>
#     </tr>
#     <tr>
#       <th id="T_662eb_level

# %% [markdown]
# # EDA

# %%
clean_df = pd.read_csv("cleaned_data.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
clean_df.head()
# Out:
#          username                                        clean_tweet  \
# 0  best_of_mltshp                       artful covid false knees via
# 1    bluum_edtech  lived connected world classrooms today incredi...
# 2    demonwings17  stones cascade form soliloquy covidcrow shriek...
# 3    bluum_edtech  new covid hdbaset smart system allinone av con...
# 4    bluum_edtech  going txla visit troxell booth see team austin...
#
#                           hashtags     date  swears_count  year  month day  \
# 0                               []  2019-03             0  2019      3   9
# 1  ['troxell', 'txla19', 'edtech']  2019-04             0  2019      4  12
# 2           ['bardbits', 'prompt']  2019-04             0  2019      4  19
# 3                   ['advantage7']  2019-04             0  2019      4   3
# 4  ['txla19', 'troxell', 'edtech']  2019-04             0  2019      4  10
#
#    include_covid
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True

# %%
import plotly.express as pex

# %%
df_c = clean_df.copy()
def remove_april(text):
  if date == "2020-04"

# %%
df_c = clean_df[clean_df["date"]!="2022-04"]
fig = pex.histogram(data_frame=df_c,x="date",title="Tweets count per month",color = "include_covid")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5362779b-0bcc-49d6-b1f8-e170eb91a5ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5362779b-0bcc-49d6-b1f8-e170eb91a5ba")) {                    Plotly.newPlot(                        "5362779b-0bcc-49d6-b1f8-e170eb91a5ba",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"include_covid=True<br>date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"True","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"True","offsetgroup":"True","orientation":"v","showlegend":true,"x":["2019-03","2019-04","2019-04","2019-04","2019-04","2019-06","2019-06","2019-07","2019-08","2019-11","2019-11","2019-11","2020-01","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-02","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020-03","2020 ...
